# %%
import json
from datasets import Dataset
import os
from transformers import AutoTokenizer

# %%
PROCESSED_DATA_FOLDER = os.path.join("../data", "processed")
ANNOTATION_FILE = os.path.join(PROCESSED_DATA_FOLDER, "all.json")
OUTPUT_DATASET_FOLDER = os.path.join("../data", "ner_dataset")

# %%
MODEL_CHECKPOINT = "dmis-lab/biobert-base-cased-v1.1"
LABELS = ["CONDITION", "DRUG", "LAB_TEST", "VALUE", "OPERATOR", "PROCEDURE", "DEMOGRAPHIC"]

# %%
with open(ANNOTATION_FILE, 'r', encoding='utf-8') as f:
    raw_data = json.load(f)

# %%
raw_data
# Out:
# [{'text': 'Inclusion Criteria:', 'entities': []},
#  {'text': 'University students at school',
#   'entities': [{'label': 'demographic', 'entity': 'University students'}]},
#  {'text': 'Exclusion Criteria:', 'entities': []},
#  {'text': 'Smoking (≥1 cigarette/week);',
#   'entities': [{'label': 'demographic', 'entity': 'Smoking'},
#    {'label': 'operator', 'entity': '≥'},
#    {'label': 'value', 'entity': '1 cigarette/week'}]},
#  {'text': 'heavy alcohol consumption (>224 g/week for men and >168 g/week for women);',
#   'entities': [{'label': 'demographic', 'entity': 'men'},
#    {'label': 'demographic', 'entity': 'women'},
#    {'label': 'operator', 'entity': '>'},
#    {'label': 'value', 'entity': '224 g/week'},
#    {'label': 'operator', 'entity': '>'},
#    {'label': 'value', 'entity': '168 g/week'}]},
#  {'text': 'Inclusion Criteria:', 'entities': []},
#  {'text': '≥18years old',
#   'entities': [{'label': 'demographic', 'entity': '≥18years old'}]},
#  {'text': 'Histopathologically confirmed FIGO II-IV stage primary ovarian cancer peritoneal or fallopian tube cancer',
#   'entities': [{'label': 'condition', 'entity': 'ovarian cancer'},
#    {'label': 'condition', 'entity': 'peritoneal'},
#    {'label': 'condition', 'entity': 'fallopian tube cancer'}]},
#  {'text': 'Patients who underwent primary tumor reduction or intermediate tumor reduction with satisfactory results (R0/R1) within 15 days after surgery',
#   'entities': [{'label': 'procedure', 'entity': 'primary tumor reduction'},
#    {'label': 'procedure', 'entity': 'intermediate tumor reduction'},
#    {'label': 'procedure', 'entity': 'surgery'}]},
#  {'text': 'After tumor reduction, the physician assessed that chemotherapy was not suitable or the patient was unwilling to receive chemotherapy',
#   'entities': [{'label': 'procedure', 'entity': 'tumor reduction'},
#    {'label': 'procedure', 'entity': 'chemotherapy'}]},
#  {'text': 'Life expectancy is 3 months',
#   'entities': [{'label': 'value', 'entity': '3 months'}]},
#  {'text': 'Liver and kidney function :', 'entities': []},
#  {'text': 'AST and ALT 3 times the upper limit of normal value or 5 times the upper limit of normal value in the presence of liver metastasis; T',
#   'entities': [{'label': 'lab_test', 'entity': 'AST'},
#    {'label': 'lab_test', 'entity': 'ALT'},
#    {'label': 'value', 'entity': '3 times the upper limit of normal'},
#    {'label': 'value', 'entity': '5 times the upper limit of normal'},
#    {'label': 'condition', 'entity': 'liver metastasis'}]},
#  {'text': 'he upper limit of total bilirubin 3 times normal value;',
#   'entities': [{'label': 'lab_test', 'entity': 'total bilirubin'},
#    {'label': 'value', 'entity': '3 times normal value'}]},
#  {'text': 'Serum creatinine is 3 times the upper limit of normal',
#   'entities': [{'label': 'lab_test', 'entity': 'Serum creatinine'},
#    {'label': 'value', 'entity': '3 times the upper limit of normal'}]},
#  {'text': 'No other tumors, no history of other malignant tumors (except non-melanoma skin cancer in situ cervical cancer or other cancers that have received curative treatment and have no signs of disease for at least 5 years)',
#   'entities': [{'label': 'condition', 'entity': 'tumors'},
#    {'label': 'condition', 'entity': 'malignant tumors'},
#    {'label': 'condition', 'entity': 'non-melanoma skin cancer'},
#    {'label': 'condition', 'entity': 'in situ cervical cancer'},
#    {'label': 'condition', 'entity': 'cancers'},
#    {'label': 'procedure', 'entity': 'curative treatment'},
#    {'label': 'value', 'entity': 'at least 5 years'}]},
#  {'text': 'Voluntarily participate in the study and sign the informed consent',
#   'entities': []},
#  {'text': 'Exclusion Criteria:', 'entities': []},
#  {'text': 'Breastfeeding women during pregnancy',
#   'entities': [{'label': 'demographic', 'entity': 'Breastfeeding women'},
#    {'label': 'demographic', 'entity': 'pregnancy'}]},
#  {'text': 'Recurrent ovarian cancer',
#   'entities': [{'label': 'condition', 'entity': 'Recurrent ovarian cancer'}]},
#  {'text': 'Known allergy to the study drug;',
#   'entities': [{'label': 'drug', 'entity': 'study drug'}]},
#  {'text': 'Central nervous system diseases or brain metastases;',
#   'entities': [{'label': 'condition',
#     'entity': 'Central nervous system diseases'},
#    {'label': 'condition', 'entity': 'brain metastases'}]},
#  {'text': 'History of abdominal/pelvic radiotherapy;',
#   'entities': [{'label': 'procedure', 'entity': 'radiotherapy'}]},
#  {'text': 'History of organ transplantation history of immune deficiency disease requiring systemic steroid therapy',
#   'entities': [{'label': 'procedure', 'entity': 'organ transplantation'},
#    {'label': 'condition', 'entity': 'immune deficiency disease'},
#    {'label': 'drug', 'entity': 'steroid'}]},
#  {'text': 'severe uncontrolled hypertension, uncontrolled diabetes mellitus, and clinically significant cardiovascular and cerebrovascular diseases;',
#   'entities': [{'label': 'condition', 'entity': 'uncontrolled hypertension'},
#    {'label': 'condition', 'entity': 'uncontrolled diabetes mellitus'},
#    {'label': 'condition',
#     'entity': 'cardiovascular and cerebrovascular diseases'}]},
#  {'text': 'History of other malignant tumors within 5 years (except for cured skin basal cell carcinoma and cervical carcinoma in situ);',
#   'entities': [{'label': 'condition', 'entity': 'malignant tumors'},
#    {'label': 'value', 'entity': '5 years'},
#    {'label': 'condition', 'entity': 'skin basal cell carcinoma'},
#    {'label': 'condition', 'entity': 'cervical carcinoma in situ'}]},
#  {'text': 'Any other factors that the investigator believes are not appropriate for participation in the study.',
#   'entities': []},
#  {'text': 'Inclusion Criteria:', 'entities': []},
#  {'text': 'Sleep complaints and a score of >5 on the Pittsburgh Sleep Quality Index',
#   'entities': [{'label': 'condition', 'entity': 'Sleep complaints'},
#    {'label': 'lab_test', 'entity': 'Pittsburgh Sleep Quality Index'},
#    {'label': 'operator', 'entity': '>'},
#    {'label': 'value', 'entity': '5'}]},
#  {'text': 'Exclusion Criteria:', 'entities': []},
#  {'text': 'Any medical condition that could contribute to sleep problems (e.g., pain, respiratory problems, hyperthyroidism)',
#   'entities': [{'label': 'condition', 'entity': 'medical condition'},
#    {'label': 'condition', 'entity': 'sleep problems'},
#    {'label': 'condition', 'entity': 'pain'},
#    {'label': 'condition', 'entity': 'respiratory problems'},
#    {'label': 'condition', 'entity': 'hyperthyroidism'}]},
#  {'text': 'Use of medications that could affect sleep (e.g., stimulants, sedatives)',
#   'entities': [{'label': 'drug', 'entity': 'medications'},
#    {'label': 'drug', 'entity': 'stimulants'},
#    {'label': 'drug', 'entity': 'sedatives'}]},
#  {'text': 'A diagnosis of a sleep disorder other than insomnia (e.g., obstructive sleep apnea)',
#   'entities': [{'label': 'condition', 'entity': 'sleep disorder'},
#    {'label': 'condition', 'entity': 'insomnia'},
#    {'label': 'condition', 'entity': 'obstructive sleep apnea'}]},
#  {'text': 'Inclusion Criteria:', 'entities': []},
#  {'text': 'Diagnosis of moderate to severe chronic periodontitis',
#   'entities': [{'label': 'condition', 'entity': 'chronic periodontitis'}]},
#  {'text': 'At least 20 natural teeth',
#   'entities': [{'label': 'value', 'entity': 'At least 20'}]},
#  {'text': 'Probing depth of ≥5 mm in at least four sites',
#   'entities': [{'label': 'lab_test', 'entity': 'Probing depth'},
#    {'label': 'operator', 'entity': '≥'},
#    {'label': 'value', 'entity': '5 mm'}]},
#  {'text': 'Exclusion Criteria:', 'entities': []},
#  {'text': 'Systemic conditions that could affect periodontal health (e.g., diabetes, immunosuppression)',
#   'entities': [{'label': 'condition', 'entity': 'Systemic conditions'},
#    {'label': 'condition', 'entity': 'diabetes'},
#    {'label': 'condition', 'entity': 'immunosuppression'}]},
#  {'text': 'Use of medications that could affect periodontal health (e.g., phenytoin, cyclosporine)',
#   'entities': [{'label': 'drug', 'entity': 'medications'},
#    {'label': 'drug', 'entity': 'phenytoin'},
#    {'label': 'drug', 'entity': 'cyclosporine'}]},
#  {'text': 'Pregnancy or lactation',
#   'entities': [{'label': 'demographic', 'entity': 'Pregnancy'},
#    {'label': 'demographic', 'entity': 'lactation'}]},
#  {'text': 'Smoking',
#   'entities': [{'label': 'demographic', 'entity': 'Smoking'}]},
#  {'text': 'History of periodontal surgery in the preceding 12 months',
#   'entities': [{'label': 'procedure', 'entity': 'periodontal surgery'},
#    {'label': 'value', 'entity': '12 months'}]},
#  {'text': 'Inclusion Criteria:', 'entities': []},
#  {'text': 'Histologically confirmed invasive carcinoma of the breast',
#   'entities': [{'label': 'condition',
#     'entity': 'invasive carcinoma of the breast'}]},
#  {'text': 'HER2-positive tumor',
#   'entities': [{'label': 'condition', 'entity': 'HER2-positive tumor'}]},
#  {'text': 'Adequate organ function', 'entities': []},
#  {'text': 'Exclusion Criteria:', 'entities': []},
#  {'text': 'Metastatic disease',
#   'entities': [{'label': 'condition', 'entity': 'Metastatic disease'}]},
#  {'text': 'Prior treatment with Herceptin (trastuzumab) or other HER2-targeted therapy',
#   'entities': [{'label': 'drug', 'entity': 'Herceptin'},
#    {'label': 'drug', 'entity': 'trastuzumab'},
#    {'label': 'drug', 'entity': 'HER2-targeted therapy'}]},
#  {'text': 'History of other malignancy within the past 5 years',
#   'entities': [{'label': 'condition', 'entity': 'malignancy'},
#    {'label': 'value', 'entity': '5 years'}]},
#  {'text': 'Inclusion Criteria:', 'entities': []},
#  {'text': "A clinical diagnosis of Huntington's disease (HD) confirmed by genetic testing",
#   'entities': [{'label': 'condition', 'entity': "Huntington's disease (HD)"},
#    {'label': 'procedure', 'entity': 'genetic testing'}]},
#  {'text': "A score of ≥5 on the Unified Huntington's Disease Rating Scale (UHDRS) motor subscale",
#   'entities': [{'label': 'lab_test',
#     'entity': "Unified Huntington's Disease Rating Scale (UHDRS) motor subscale"},
#    {'label': 'operator', 'entity': '≥'},
#    {'label': 'value', 'entity': '5'}]},
#  {'text': 'A score of ≥2 on the UHDRS cognitive subscale',
#   'entities': [{'label': 'lab_test', 'entity': 'UHDRS cognitive subscale'},
#    {'label': 'operator', 'entity': '≥'},
#    {'label': 'value', 'entity': '2'}]},
#  {'text': 'A score of ≥2 on the UHDRS functional subscale',
#   'entities': [{'label': 'lab_test', 'entity': 'UHDRS functional subscale'},
#    {'label': 'operator', 'entity': '≥'},
#    {'label': 'value', 'entity': '2'}]},
#  {'text': 'Exclusion Criteria:', 'entities': []},
#  {'text': 'Any other neurological or psychiatric condition that could interfere with the assessment of HD symptoms',
#   'entities': [{'label': 'condition',
#     'entity': 'neurological or psychiatric condition'},
#    {'label': 'condition', 'entity': 'HD symptoms'}]},
#  {'text': 'Use of any medication that could interfere with the assessment of HD symptoms',
#   'entities': [{'label': 'drug', 'entity': 'medication'},
#    {'label': 'condition', 'entity': 'HD symptoms'}]},
#  {'text': 'A history of substance abuse or dependence',
#   'entities': [{'label': 'condition', 'entity': 'substance abuse'},
#    {'label': 'condition', 'entity': 'dependence'}]},
#  {'text': 'Pregnancy or lactation',
#   'entities': [{'label': 'demographic', 'entity': 'Pregnancy'},
#    {'label': 'demographic', 'entity': 'lactation'}]},
#  {'text': 'Inclusion Criteria:', 'entities': []},
#  {'text': 'Adult patients (≥18 years of age) with a diagnosis of ARDS according to the Berlin definition.',
#   'entities': [{'label': 'demographic', 'entity': 'Adult patients'},
#    {'label': 'demographic', 'entity': '≥18 years of age'},
#    {'label': 'condition', 'entity': 'ARDS'}]},
#  {'text': 'PaO2/FiO2 ratio < 200 mmHg with a PEEP ≥ 5 cmH2O.',
#   'entities': [{'label': 'lab_test', 'entity': 'PaO2/FiO2 ratio'},
#    {'label': 'lab_test', 'entity': 'PEEP'},
#    {'label': 'operator', 'entity': '<'},
#    {'label': 'value', 'entity': '200 mmHg'},
#    {'label': 'operator', 'entity': '≥'},
#    {'label': 'value', 'entity': '5 cmH2O'}]},
#  {'text': 'Bilateral opacities on chest radiograph or CT scan not fully explained by effusions, lobar/lung collapse, or nodules.',
#   'entities': [{'label': 'condition', 'entity': 'Bilateral opacities'},
#    {'label': 'procedure', 'entity': 'chest radiograph'},
#    {'label': 'procedure', 'entity': 'CT scan'},
#    {'label': 'condition', 'entity': 'effusions'},
#    {'label': 'condition', 'entity': 'lobar/lung collapse'},
#    {'label': 'condition', 'entity': 'nodules'}]},
#  {'text': 'Respiratory failure not fully explained by cardiac failure or fluid overload.',
#   'entities': [{'label': 'condition', 'entity': 'Respiratory failure'},
#    {'label': 'condition', 'entity': 'cardiac failure'},
#    {'label': 'condition', 'entity': 'fluid overload'}]},
#  {'text': 'Exclusion Criteria:', 'entities': []},
#  {'text': 'Pregnancy.',
#   'entities': [{'label': 'demographic', 'entity': 'Pregnancy'}]},
#  {'text': 'Morbid obesity (body mass index > 40 kg/m2).',
#   'entities': [{'label': 'condition', 'entity': 'Morbid obesity'},
#    {'label': 'lab_test', 'entity': 'body mass index'},
#    {'label': 'operator', 'entity': '>'},
#    {'label': 'value', 'entity': '40 kg/m2'}]},
#  {'text': 'Severe chronic obstructive pulmonary disease (COPD) or asthma.',
#   'entities': [{'label': 'condition',
#     'entity': 'chronic obstructive pulmonary disease (COPD)'},
#    {'label': 'condition', 'entity': 'asthma'}]},
#  {'text': 'Neuromuscular disease that affects breathing.',
#   'entities': [{'label': 'condition', 'entity': 'Neuromuscular disease'}]},
#  {'text': 'Inclusion Criteria:', 'entities': []},
#  {'text': 'Patients must have a diagnosis of periodontitis and have at least 20 teeth.',
#   'entities': [{'label': 'condition', 'entity': 'periodontitis'},
#    {'label': 'value', 'entity': 'at least 20'}]},
#  {'text': 'Patients must have at least four teeth with probing depth ≥ 5 mm and clinical attachment loss ≥ 3 mm.',
#   'entities': [{'label': 'lab_test', 'entity': 'probing depth'},
#    {'label': 'operator', 'entity': '≥'},
#    {'label': 'value', 'entity': '5 mm'},
#    {'label': 'lab_test', 'entity': 'clinical attachment loss'},
#    {'label': 'operator', 'entity': '≥'},
#    {'label': 'value', 'entity': '3 mm'}]},
#  {'text': 'Patients must be in good general health.', 'entities': []},
#  {'text': 'Exclusion Criteria:', 'entities': []},
#  {'text': 'Patients who are pregnant or lactating.',
#   'entities': [{'label': 'demographic', 'entity': 'pregnant'},
#    {'label': 'demographic', 'entity': 'lactating'}]},
#  {'text': 'Patients who have a systemic disease that could affect the periodontium.',
#   'entities': [{'label': 'condition', 'entity': 'systemic disease'}]},
#  {'text': 'Patients who are taking medications that could affect the periodontium.',
#   'entities': [{'label': 'drug', 'entity': 'medications'}]},
#  {'text': 'Patients who have received periodontal treatment in the past 6 months.',
#   'entities': [{'label': 'procedure', 'entity': 'periodontal treatment'},
#    {'label': 'value', 'entity': '6 months'}]},
#  {'text': 'Inclusion Criteria:', 'entities': []},
#  {'text': '- Histologically confirmed HER2-positive metastatic breast cancer',
#   'entities': [{'label': 'condition',
#     'entity': 'HER2-positive metastatic breast cancer'}]},
#  {'text': '- Progression of disease after prior trastuzumab-based therapy',
#   'entities': [{'label': 'condition', 'entity': 'Progression of disease'},
#    {'label': 'drug', 'entity': 'trastuzumab-based therapy'}]},
#  {'text': '- Measurable disease per RECIST 1.1 criteria',
#   'entities': [{'label': 'condition', 'entity': 'Measurable disease'}]},
#  {'text': '- ECOG performance status 0-1',
#   'entities': [{'label': 'lab_test', 'entity': 'ECOG performance status'},
#    {'label': 'value', 'entity': '0-1'}]},
#  {'text': '- LVEF ≥50%',
#   'entities': [{'label': 'lab_test', 'entity': 'LVEF'},
#    {'label': 'operator', 'entity': '≥'},
#    {'label': 'value', 'entity': '50%'}]},
#  {'text': 'Exclusion Criteria:', 'entities': []},
#  {'text': '- Prior treatment with lapatinib',
#   'entities': [{'label': 'drug', 'entity': 'lapatinib'}]},
#  {'text': '- Active brain metastases',
#   'entities': [{'label': 'condition', 'entity': 'Active brain metastases'}]},
#  {'text': '- History of significant cardiac disease',
#   'entities': [{'label': 'condition', 'entity': 'cardiac disease'}]},
#  {'text': '- Uncontrolled hypertension',
#   'entities': [{'label': 'condition', 'entity': 'Uncontrolled hypertension'}]},
#  {'text': '- Known hypersensitivity to lapatinib or its components',
#   'entities': [{'label': 'condition',
#     'entity': 'hypersensitivity to lapatinib'}]},
#  {'text': 'Inclusion Criteria:', 'entities': []},
#  {'text': '- Histologically confirmed diagnosis of chronic periodontitis',
#   'entities': [{'label': 'condition', 'entity': 'chronic periodontitis'}]},
#  {'text': '- At least 20 natural teeth',
#   'entities': [{'label': 'value', 'entity': 'At least 20'}]},
#  {'text': '- Probing depth of 5-8 mm in at least 4 sites in different quadrants',
#   'entities': [{'label': 'lab_test', 'entity': 'Probing depth'},
#    {'label': 'value', 'entity': '5-8 mm'}]},
#  {'text': '- Clinical attachment level of ≥ 3 mm in the same sites',
#   'entities': [{'label': 'lab_test', 'entity': 'Clinical attachment level'},
#    {'label': 'operator', 'entity': '≥'},
#    {'label': 'value', 'entity': '3 mm'}]},
#  {'text': '- Bleeding on probing in the same sites',
#   'entities': [{'label': 'condition', 'entity': 'Bleeding on probing'}]},
#  {'text': 'Exclusion Criteria:', 'entities': []},
#  {'text': '- Systemic diseases that may affect periodontal tissues',
#   'entities': [{'label': 'condition', 'entity': 'Systemic diseases'}]},
#  {'text': '- Use of medications that may affect periodontal tissues',
#   'entities': [{'label': 'drug', 'entity': 'medications'}]},
#  {'text': '- Pregnancy or lactation',
#   'entities': [{'label': 'demographic', 'entity': 'Pregnancy'},
#    {'label': 'demographic', 'entity': 'lactation'}]},
#  {'text': '- Smoking',
#   'entities': [{'label': 'demographic', 'entity': 'Smoking'}]},
#  {'text': '- Previous periodontal surgery',
#   'entities': [{'label': 'procedure', 'entity': 'periodontal surgery'}]},
#  {'text': 'Inclusion Criteria:', 'entities': []},
#  {'text': '- Patients with a diagnosis of chronic periodontitis',
#   'entities': [{'label': 'condition', 'entity': 'chronic periodontitis'}]},
#  {'text': '- Patients with at least 20 teeth',
#   'entities': [{'label': 'value', 'entity': 'at least 20'}]},
#  {'text': '- Patients with at least 4 sites with probing depth ≥ 5 mm and clinical attachment loss ≥ 3 mm',
#   'entities': [{'label': 'lab_test', 'entity': 'probing depth'},
#    {'label': 'operator', 'entity': '≥'},
#    {'label': 'value', 'entity': '5 mm'},
#    {'label': 'lab_test', 'entity': 'clinical attachment loss'},
#    {'label': 'operator', 'entity': '≥'},
#    {'label': 'value', 'entity': '3 mm'}]},
#  {'text': 'Exclusion Criteria:', 'entities': []},
#  {'text': '- Patients with systemic diseases that could affect periodontal tissues',
#   'entities': [{'label': 'condition', 'entity': 'systemic diseases'}]},
#  {'text': '- Patients taking medications that could affect periodontal tissues',
#   'entities': [{'label': 'drug', 'entity': 'medications'}]},
#  {'text': '- Pregnant or breastfeeding women',
#   'entities': [{'label': 'demographic',
#     'entity': 'Pregnant or breastfeeding women'}]},
#  {'text': '- Smokers',
#   'entities': [{'label': 'demographic', 'entity': 'Smokers'}]},
#  {'text': 'Inclusion criteria:', 'entities': []},
#  {'text': '- Patients with a diagnosis of periodontitis',
#   'entities': [{'label': 'condition', 'entity': 'periodontitis'}]},
#  {'text': '- Patients with at least 20 teeth',
#   'entities': [{'label': 'value', 'entity': 'at least 20'}]},
#  {'text': '- Patients with at least 4 teeth with a probing depth of 5 mm or more',
#   'entities': [{'label': 'lab_test', 'entity': 'probing depth'},
#    {'label': 'value', 'entity': '5 mm or more'}]},
#  {'text': '- Patients with a clinical attachment loss of 3 mm or more',
#   'entities': [{'label': 'lab_test', 'entity': 'clinical attachment loss'},
#    {'label': 'value', 'entity': '3 mm or more'}]},
#  {'text': 'Exclusion criteria:', 'entities': []},
#  {'text': '- Patients with any systemic disease that may affect the periodontium',
#   'entities': [{'label': 'condition', 'entity': 'systemic disease'}]},
#  {'text': '- Patients who are taking any medication that may affect the periodontium',
#   'entities': [{'label': 'drug', 'entity': 'medication'}]},
#  {'text': '- Patients who are pregnant or lactating',
#   'entities': [{'label': 'demographic', 'entity': 'pregnant or lactating'}]},
#  {'text': '- Patients who are smokers',
#   'entities': [{'label': 'demographic', 'entity': 'smokers'}]},
#  {'text': 'Inclusion Criteria:', 'entities': []},
#  {'text': '- Histologically or cytologically confirmed diagnosis of adenocarcinoma of the colon or rectum',
#   'entities': [{'label': 'condition',
#     'entity': 'adenocarcinoma of the colon or rectum'}]},
#  {'text': '- Metastatic disease not amenable to curative resection',
#   'entities': [{'label': 'condition', 'entity': 'Metastatic disease'},
#    {'label': 'procedure', 'entity': 'curative resection'}]},
#  {'text': '- No prior chemotherapy for metastatic disease',
#   'entities': [{'label': 'procedure', 'entity': 'chemotherapy'},
#    {'label': 'condition', 'entity': 'metastatic disease'}]},
#  {'text': '- ECOG performance status 0-2',
#   'entities': [{'label': 'lab_test', 'entity': 'ECOG performance status'},
#    {'label': 'value', 'entity': '0-2'}]},
#  {'text': '- Age ≥18 years',
#   'entities': [{'label': 'demographic', 'entity': 'Age ≥18 years'}]},
#  {'text': '- Life expectancy ≥3 months',
#   'entities': [{'label': 'operator', 'entity': '≥'},
#    {'label': 'value', 'entity': '3 months'}]},
#  {'text': '- Adequate organ function (hematologic, renal, and hepatic)',
#   'entities': []},
#  {'text': 'Exclusion Criteria:', 'entities': []},
#  {'text': '- Prior adjuvant chemotherapy with an oxaliplatin-containing regimen within the last 12 months',
#   'entities': [{'label': 'procedure', 'entity': 'adjuvant chemotherapy'},
#    {'label': 'drug', 'entity': 'oxaliplatin-containing regimen'},
#    {'label': 'value', 'entity': '12 months'}]},
#  {'text': '- Known central nervous system metastases',
#   'entities': [{'label': 'condition',
#     'entity': 'central nervous system metastases'}]},
#  {'text': '- History of other malignancy within the last 5 years, except for adequately treated non-melanoma skin cancer or in situ cervical cancer',
#   'entities': [{'label': 'condition', 'entity': 'malignancy'},
#    {'label': 'value', 'entity': '5 years'},
#    {'label': 'condition', 'entity': 'non-melanoma skin cancer'},
#    {'label': 'condition', 'entity': 'in situ cervical cancer'}]},
#  {'text': '- Active, uncontrolled infection',
#   'entities': [{'label': 'condition', 'entity': 'uncontrolled infection'}]},
#  {'text': '- Known hypersensitivity to any of the study drugs',
#   'entities': [{'label': 'condition', 'entity': 'hypersensitivity'},
#    {'label': 'drug', 'entity': 'study drugs'}]},
#  {'text': 'Inclusion Criteria:', 'entities': []},
#  {'text': '- Patients with a diagnosis of chronic periodontitis',
#   'entities': [{'label': 'condition', 'entity': 'chronic periodontitis'}]},
#  {'text': '- At least 20 teeth present',
#   'entities': [{'label': 'value', 'entity': 'At least 20'}]},
#  {'text': '- At least 4 sites with probing depth ≥ 5 mm and clinical attachment loss ≥ 3 mm',
#   'entities': [{'label': 'lab_test', 'entity': 'probing depth'},
#    {'label': 'operator', 'entity': '≥'},
#    {'label': 'value', 'entity': '5 mm'},
#    {'label': 'lab_test', 'entity': 'clinical attachment loss'},
#    {'label': 'operator', 'entity': '≥'},
#    {'label': 'value', 'entity': '3 mm'}]},
#  {'text': 'Exclusion Criteria:', 'entities': []},
#  {'text': '- Systemic diseases that may influence the course of periodontitis',
#   'entities': [{'label': 'condition', 'entity': 'Systemic diseases'},
#    {'label': 'condition', 'entity': 'periodontitis'}]},
#  {'text': '- Use of drugs known to influence the periodontium',
#   'entities': [{'label': 'drug', 'entity': 'drugs'}]},
#  {'text': '- Pregnancy or lactation',
#   'entities': [{'label': 'demographic', 'entity': 'Pregnancy'},
#    {'label': 'demographic', 'entity': 'lactation'}]},
#  {'text': '- Smoking',
#   'entities': [{'label': 'demographic', 'entity': 'Smoking'}]},
#  {'text': '- Periodontal treatment within the last 6 months',
#   'entities': [{'label': 'procedure', 'entity': 'Periodontal treatment'},
#    {'label': 'value', 'entity': '6 months'}]},
#  {'text': 'Inclusion Criteria:', 'entities': []},
#  {'text': '- Histologically confirmed diagnosis of pancreatic adenocarcinoma',
#   'entities': [{'label': 'condition', 'entity': 'pancreatic adenocarcinoma'}]},
#  {'text': '- Locally advanced, unresectable, or metastatic disease',
#   'entities': [{'label': 'condition',
#     'entity': 'Locally advanced, unresectable, or metastatic disease'}]},
#  {'text': '- No prior systemic therapy for pancreatic cancer',
#   'entities': [{'label': 'drug', 'entity': 'systemic therapy'},
#    {'label': 'condition', 'entity': 'pancreatic cancer'}]},
#  {'text': '- Age ≥18 years',
#   'entities': [{'label': 'demographic', 'entity': 'Age ≥18 years'}]},
#  {'text': '- ECOG performance status 0 or 1',
#   'entities': [{'label': 'lab_test', 'entity': 'ECOG performance status'},
#    {'label': 'value', 'entity': '0 or 1'}]},
#  {'text': '- Life expectancy ≥3 months',
#   'entities': [{'label': 'operator', 'entity': '≥'},
#    {'label': 'value', 'entity': '3 months'}]},
#  {'text': '- Adequate organ function (bone marrow, liver, and kidney)',
#   'entities': []},
#  {'text': 'Exclusion Criteria:', 'entities': []},
#  {'text': '- Prior radiation therapy to the pancreas',
#   'entities': [{'label': 'procedure', 'entity': 'radiation therapy'}]},
#  {'text': '- Active brain metastases',
#   'entities': [{'label': 'condition', 'entity': 'Active brain metastases'}]},
#  {'text': '- History of another malignancy within the past 5 years, with the exception of adequately treated non-melanoma skin cancer or cervical carcinoma in situ',
#   'entities': [{'label': 'condition', 'entity': 'malignancy'},
#    {'label': 'value', 'entity': '5 years'},
#    {'label': 'condition', 'entity': 'non-melanoma skin cancer'},
#    {'label': 'condition', 'entity': 'cervical carcinoma in situ'}]},
#  {'text': '- Known hypersensitivity to gemcitabine or nab-paclitaxel',
#   'entities': [{'label': 'condition', 'entity': 'hypersensitivity'},
#    {'label': 'drug', 'entity': 'gemcitabine'},
#    {'label': 'drug', 'entity': 'nab-paclitaxel'}]},
#  {'text': 'Inclusion Criteria:', 'entities': []},
#  {'text': '- Histologically confirmed diagnosis of advanced or metastatic non-small cell lung cancer (NSCLC)',
#   'entities': [{'label': 'condition',
#     'entity': 'advanced or metastatic non-small cell lung cancer (NSCLC)'}]},
#  {'text': '- Progression of disease after at least one prior line of systemic therapy',
#   'entities': [{'label': 'condition', 'entity': 'Progression of disease'},
#    {'label': 'drug', 'entity': 'systemic therapy'}]},
#  {'text': '- Presence of a sensitizing EGFR mutation (exon 19 deletion or L858R mutation)',
#   'entities': [{'label': 'condition',
#     'entity': 'sensitizing EGFR mutation (exon 19 deletion or L858R mutation)'}]},
#  {'text': '- Age ≥ 18 years',
#   'entities': [{'label': 'demographic', 'entity': 'Age ≥ 18 years'}]},
#  {'text': '- ECOG performance status of 0-2',
#   'entities': [{'label': 'lab_test', 'entity': 'ECOG performance status'},
#    {'label': 'value', 'entity': '0-2'}]},
#  {'text': '- Life expectancy of at least 3 months',
#   'entities': [{'label': 'value', 'entity': 'at least 3 months'}]},
#  {'text': '- Adequate organ function', 'entities': []},
#  {'text': 'Exclusion Criteria:', 'entities': []},
#  {'text': '- Prior treatment with an EGFR tyrosine kinase inhibitor (TKI)',
#   'entities': [{'label': 'drug',
#     'entity': 'EGFR tyrosine kinase inhibitor (TKI)'}]},
#  {'text': '- Known T790M resistance mutation',
#   'entities': [{'label': 'condition', 'entity': 'T790M resistance mutation'}]},
#  {'text': '- Active brain metastases',
#   'entities': [{'label': 'condition', 'entity': 'Active brain metastases'}]},
#  {'text': '- History of interstitial lung disease',
#   'entities': [{'label': 'condition', 'entity': 'interstitial lung disease'}]},
#  {'text': '- Significant cardiovascular disease',
#   'entities': [{'label': 'condition', 'entity': 'cardiovascular disease'}]},
#  {'text': 'Inclusion Criteria:', 'entities': []},
#  {'text': '- Histologically or cytologically confirmed diagnosis of metastatic colorectal cancer',
#   'entities': [{'label': 'condition',
#     'entity': 'metastatic colorectal cancer'}]},
#  {'text': '- Progression of disease after standard therapies, including fluoropyrimidine, oxaliplatin, irinotecan, and a biologic agent (if appropriate)',
#   'entities': [{'label': 'condition', 'entity': 'Progression of disease'},
#    {'label': 'drug', 'entity': 'fluoropyrimidine'},
#    {'label': 'drug', 'entity': 'oxaliplatin'},
#    {'label': 'drug', 'entity': 'irinotecan'},
#    {'label': 'drug', 'entity': 'biologic agent'}]},
#  {'text': '- Age ≥18 years',
#   'entities': [{'label': 'demographic', 'entity': 'Age ≥18 years'}]},
#  {'text': '- ECOG performance status 0-1',
#   'entities': [{'label': 'lab_test', 'entity': 'ECOG performance status'},
#    {'label': 'value', 'entity': '0-1'}]},
#  {'text': '- Life expectancy ≥3 months',
#   'entities': [{'label': 'operator', 'entity': '≥'},
#    {'label': 'value', 'entity': '3 months'}]},
#  {'text': '- Adequate organ and bone marrow function', 'entities': []},
#  {'text': 'Exclusion Criteria:', 'entities': []},
#  {'text': '- Prior treatment with regorafenib',
#   'entities': [{'label': 'drug', 'entity': 'regorafenib'}]},
#  {'text': '- Known BRAF V600E mutation',
#   'entities': [{'label': 'condition', 'entity': 'BRAF V600E mutation'}]},
#  {'text': '- Active brain metastases',
#   'entities': [{'label': 'condition', 'entity': 'Active brain metastases'}]},
#  {'text': '- History of another malignancy within the past 5 years, except for adequately treated non-melanoma skin cancer or in situ cervical cancer',
#   'entities': [{'label': 'condition', 'entity': 'malignancy'},
#    {'label': 'value', 'entity': '5 years'},
#    {'label': 'condition', 'entity': 'non-melanoma skin cancer'},
#    {'label': 'condition', 'entity': 'in situ cervical cancer'}]},
#  {'text': '- Uncontrolled hypertension',
#   'entities': [{'label': 'condition', 'entity': 'Uncontrolled hypertension'}]},
#  {'text': 'Inclusion Criteria:', 'entities': []},
#  {'text': '- Diagnosis of chronic periodontitis',
#   'entities': [{'label': 'condition', 'entity': 'chronic periodontitis'}]},
#  {'text': '- At least 20 natural teeth',
#   'entities': [{'label': 'value', 'entity': 'At least 20'}]},
#  {'text': '- Probing depth (PD) ≥ 5 mm in at least 4 sites',
#   'entities': [{'label': 'lab_test', 'entity': 'Probing depth (PD)'},
#    {'label': 'operator', 'entity': '≥'},
#    {'label': 'value', 'entity': '5 mm'}]},
#  {'text': '- Clinical attachment level (CAL) ≥ 3 mm in the same sites',
#   'entities': [{'label': 'lab_test',
#     'entity': 'Clinical attachment level (CAL)'},
#    {'label': 'operator', 'entity': '≥'},
#    {'label': 'value', 'entity': '3 mm'}]},
#  {'text': 'Exclusion Criteria:', 'entities': []},
#  {'text': '- Systemic diseases that could affect the periodontium',
#   'entities': [{'label': 'condition', 'entity': 'Systemic diseases'}]},
#  {'text': '- Use of drugs that could affect the periodontium',
#   'entities': [{'label': 'drug', 'entity': 'drugs'}]},
#  {'text': '- Pregnancy or lactation',
#   'entities': [{'label': 'demographic', 'entity': 'Pregnancy'},
#    {'label': 'demographic', 'entity': 'lactation'}]},
#  {'text': '- Smoking',
#   'entities': [{'label': 'demographic', 'entity': 'Smoking'}]},
#  {'text': '- Periodontal surgery in the last 12 months',
#   'entities': [{'label': 'procedure', 'entity': 'Periodontal surgery'},
#    {'label': 'value', 'entity': '12 months'}]},
#  {'text': 'Inclusion Criteria:', 'entities': []},
#  {'text': '- Histologically confirmed diagnosis of metastatic melanoma',
#   'entities': [{'label': 'condition', 'entity': 'metastatic melanoma'}]},
#  {'text': '- BRAF V600 mutation-positive',
#   'entities': [{'label': 'condition',
#     'entity': 'BRAF V600 mutation-positive'}]},
#  {'text': '- No prior systemic therapy for metastatic disease',
#   'entities': [{'label': 'drug', 'entity': 'systemic therapy'},
#    {'label': 'condition', 'entity': 'metastatic disease'}]},
#  {'text': '- Age ≥18 years',
#   'entities': [{'label': 'demographic', 'entity': 'Age ≥18 years'}]},
#  {'text': '- ECOG performance status 0 or 1',
#   'entities': [{'label': 'lab_test', 'entity': 'ECOG performance status'},
#    {'label': 'value', 'entity': '0 or 1'}]},
#  {'text': '- Life expectancy ≥3 months',
#   'entities': [{'label': 'operator', 'entity': '≥'},
#    {'label': 'value', 'entity': '3 months'}]},
#  {'text': '- Adequate organ function', 'entities': []},
#  {'text': 'Exclusion Criteria:', 'entities': []},
#  {'text': '- Uveal melanoma',
#   'entities': [{'label': 'condition', 'entity': 'Uveal melanoma'}]},
#  {'text': '- Active brain metastases',
#   'entities': [{'label': 'condition', 'entity': 'Active brain metastases'}]},
#  {'text': '- History of another malignancy within the past 5 years, except for adequately treated non-melanoma skin cancer or in situ cervical cancer',
#   'entities': [{'label': 'condition', 'entity': 'malignancy'},
#    {'label': 'value', 'entity': '5 years'},
#    {'label': 'condition', 'entity': 'non-melanoma skin cancer'},
#    {'label': 'condition', 'entity': 'in situ cervical cancer'}]},
#  {'text': '- Known hypersensitivity to dabrafenib or trametinib',
#   'entities': [{'label': 'condition', 'entity': 'hypersensitivity'},
#    {'label': 'drug', 'entity': 'dabrafenib'},
#    {'label': 'drug', 'entity': 'trametinib'}]},
#  {'text': 'Inclusion Criteria:', 'entities': []},
#  {'text': '- Patients with a diagnosis of chronic periodontitis',
#   'entities': [{'label': 'condition', 'entity': 'chronic periodontitis'}]},
#  {'text': '- At least 20 teeth',
#   'entities': [{'label': 'value', 'entity': 'At least 20'}]},
#  {'text': '- At least 4 sites with probing depth ≥ 5mm and clinical attachment loss ≥ 3mm',
#   'entities': [{'label': 'lab_test', 'entity': 'probing depth'},
#    {'label': 'operator', 'entity': '≥'},
#    {'label': 'value', 'entity': '5mm'},
#    {'label': 'lab_test', 'entity': 'clinical attachment loss'},
#    {'label': 'operator', 'entity': '≥'},
#    {'label': 'value', 'entity': '3mm'}]},
#  {'text': 'Exclusion Criteria:', 'entities': []},
#  {'text': '- Systemic diseases known to affect periodontal tissues',
#   'entities': [{'label': 'condition', 'entity': 'Systemic diseases'}]},
#  {'text': '- Medications known to affect periodontal tissues',
#   'entities': [{'label': 'drug', 'entity': 'Medications'}]},
#  {'text': '- Pregnancy or lactation',
#   'entities': [{'label': 'demographic', 'entity': 'Pregnancy'},
#    {'label': 'demographic', 'entity': 'lactation'}]},
#  {'text': '- Smoking',
#   'entities': [{'label': 'demographic', 'entity': 'Smoking'}]},
#  {'text': '- Periodontal surgery in the previous 12 months',
#   'entities': [{'label': 'procedure', 'entity': 'Periodontal surgery'},
#    {'label': 'value', 'entity': '12 months'}]},
#  {'text': 'Inclusion Criteria:', 'entities': []},
#  {'text': '- Histologically confirmed diagnosis of advanced or metastatic renal cell carcinoma (RCC) with a clear-cell component',
#   'entities': [{'label': 'condition',
#     'entity': 'advanced or metastatic renal cell carcinoma (RCC)'}]},
#  {'text': '- No prior systemic therapy for advanced RCC',
#   'entities': [{'label': 'drug', 'entity': 'systemic therapy'},
#    {'label': 'condition', 'entity': 'advanced RCC'}]},
#  {'text': '- Karnofsky Performance Status (KPS) ≥ 70%',
#   'entities': [{'label': 'lab_test',
#     'entity': 'Karnofsky Performance Status (KPS)'},
#    {'label': 'operator', 'entity': '≥'},
#    {'label': 'value', 'entity': '70%'}]},
#  {'text': '- Age ≥ 18 years',
#   'entities': [{'label': 'demographic', 'entity': 'Age ≥ 18 years'}]},
#  {'text': '- Life expectancy ≥ 3 months',
#   'entities': [{'label': 'operator', 'entity': '≥'},
#    {'label': 'value', 'entity': '3 months'}]},
#  {'text': '- Adequate organ function (hematologic, renal, and hepatic)',
#   'entities': []},
#  {'text': 'Exclusion Criteria:', 'entities': []},
#  {'text': '- Prior treatment with a VEGF-targeted therapy',
#   'entities': [{'label': 'drug', 'entity': 'VEGF-targeted therapy'}]},
#  {'text': '- Active brain metastases',
#   'entities': [{'label': 'condition', 'entity': 'Active brain metastases'}]},
#  {'text': '- History of another malignancy within the past 3 years, except for adequately treated non-melanoma skin cancer or in situ cervical cancer',
#   'entities': [{'label': 'condition', 'entity': 'malignancy'},
#    {'label': 'value', 'entity': '3 years'},
#    {'label': 'condition', 'entity': 'non-melanoma skin cancer'},
#    {'label': 'condition', 'entity': 'in situ cervical cancer'}]},
#  {'text': '- Uncontrolled hypertension',
#   'entities': [{'label': 'condition', 'entity': 'Uncontrolled hypertension'}]},
#  {'text': '- Significant cardiovascular disease',
#   'entities': [{'label': 'condition', 'entity': 'cardiovascular disease'}]},
#  {'text': 'Inclusion Criteria:', 'entities': []},
#  {'text': '- Histologically confirmed diagnosis of metastatic castration-resistant prostate cancer (mCRPC)',
#   'entities': [{'label': 'condition',
#     'entity': 'metastatic castration-resistant prostate cancer (mCRPC)'}]},
#  {'text': '- Progression of disease after treatment with at least one, and no more than two, previous chemotherapy regimens for mCRPC',
#   'entities': [{'label': 'condition', 'entity': 'Progression of disease'},
#    {'label': 'procedure', 'entity': 'chemotherapy regimens'},
#    {'label': 'condition', 'entity': 'mCRPC'}]},
#  {'text': '- Age ≥18 years',
#   'entities': [{'label': 'demographic', 'entity': 'Age ≥18 years'}]},
#  {'text': '- ECOG performance status 0-2',
#   'entities': [{'label': 'lab_test', 'entity': 'ECOG performance status'},
#    {'label': 'value', 'entity': '0-2'}]},
#  {'text': '- Life expectancy ≥3 months',
#   'entities': [{'label': 'operator', 'entity': '≥'},
#    {'label': 'value', 'entity': '3 months'}]},
#  {'text': '- Adequate organ function (bone marrow, liver, and kidney)',
#   'entities': []},
#  {'text': 'Exclusion Criteria:', 'entities': []},
#  {'text': '- Prior treatment with cabazitaxel',
#   'entities': [{'label': 'drug', 'entity': 'cabazitaxel'}]},
#  {'text': '- Active brain metastases',
#   'entities': [{'label': 'condition', 'entity': 'Active brain metastases'}]},
#  {'text': '- History of another malignancy within the past 5 years, except for adequately treated non-melanoma skin cancer or in situ cervical cancer',
#   'entities': [{'label': 'condition', 'entity': 'malignancy'},
#    {'label': 'value', 'entity': '5 years'},
#    {'label': 'condition', 'entity': 'non-melanoma skin cancer'},
#    {'label': 'condition', 'entity': 'in situ cervical cancer'}]},
#  {'text': '- Known hypersensitivity to cabazitaxel or other taxanes',
#   'entities': [{'label': 'condition', 'entity': 'hypersensitivity'},
#    {'label': 'drug', 'entity': 'cabazitaxel'},
#    {'label': 'drug', 'entity': 'taxanes'}]},
#  {'text': 'Inclusion criteria:', 'entities': []},
#  {'text': 'Patients with chronic periodontitis',
#   'entities': [{'label': 'condition', 'entity': 'chronic periodontitis'}]},
#  {'text': 'At least 20 teeth',
#   'entities': [{'label': 'value', 'entity': 'At least 20'}]},
#  {'text': 'Probing depth ≥ 5 mm in at least 4 teeth',
#   'entities': [{'label': 'lab_test', 'entity': 'Probing depth'},
#    {'label': 'operator', 'entity': '≥'},
#    {'label': 'value', 'entity': '5 mm'}]},
#  {'text': 'Clinical attachment loss ≥ 3 mm in at least 4 teeth',
#   'entities': [{'label': 'lab_test', 'entity': 'Clinical attachment loss'},
#    {'label': 'operator', 'entity': '≥'},
#    {'label': 'value', 'entity': '3 mm'}]},
#  {'text': 'Exclusion criteria:', 'entities': []},
#  {'text': 'Systemic diseases that may affect the periodontium',
#   'entities': [{'label': 'condition', 'entity': 'Systemic diseases'}]},
#  {'text': 'Medications that may affect the periodontium',
#   'entities': [{'label': 'drug', 'entity': 'Medications'}]},
#  {'text': 'Pregnancy or lactation',
#   'entities': [{'label': 'demographic', 'entity': 'Pregnancy'},
#    {'label': 'demographic', 'entity': 'lactation'}]},
#  {'text': 'Smoking',
#   'entities': [{'label': 'demographic', 'entity': 'Smoking'}]},
#  {'text': 'Previous periodontal surgery',
#   'entities': [{'label': 'procedure', 'entity': 'periodontal surgery'}]},
#  {'text': 'Inclusion Criteria:', 'entities': []},
#  {'text': '- Histologically confirmed diagnosis of locally advanced or metastatic urothelial carcinoma',
#   'entities': [{'label': 'condition',
#     'entity': 'locally advanced or metastatic urothelial carcinoma'}]},
#  {'text': '- Progression of disease during or after platinum-containing chemotherapy',
#   'entities': [{'label': 'condition', 'entity': 'Progression of disease'},
#    {'label': 'drug', 'entity': 'platinum-containing chemotherapy'}]},
#  {'text': '- Age ≥18 years',
#   'entities': [{'label': 'demographic', 'entity': 'Age ≥18 years'}]},
#  {'text': '- ECOG performance status 0-1',
#   'entities': [{'label': 'lab_test', 'entity': 'ECOG performance status'},
#    {'label': 'value', 'entity': '0-1'}]},
#  {'text': '- Life expectancy ≥3 months',
#   'entities': [{'label': 'operator', 'entity': '≥'},
#    {'label': 'value', 'entity': '3 months'}]},
#  {'text': '- Adequate organ and bone marrow function', 'entities': []},
#  {'text': 'Exclusion Criteria:', 'entities': []},
#  {'text': '- Prior treatment with an immune checkpoint inhibitor',
#   'entities': [{'label': 'drug', 'entity': 'immune checkpoint inhibitor'}]},
#  {'text': '- Active brain metastases',
#   'entities': [{'label': 'condition', 'entity': 'Active brain metastases'}]},
#  {'text': '- History of autoimmune disease',
#   'entities': [{'label': 'condition', 'entity': 'autoimmune disease'}]},
#  {'text': '- Active, uncontrolled infection',
#   'entities': [{'label': 'condition', 'entity': 'uncontrolled infection'}]},
#  {'text': '- Known hypersensitivity to pembrolizumab or its excipients',
#   'entities': [{'label': 'condition', 'entity': 'hypersensitivity'},
#    {'label': 'drug', 'entity': 'pembrolizumab'}]},
#  {'text': 'Inclusion criteria:', 'entities': []},
#  {'text': '- Patients with a diagnosis of chronic periodontitis',
#   'entities': [{'label': 'condition', 'entity': 'chronic periodontitis'}]},
#  {'text': '- At least 20 teeth',
#   'entities': [{'label': 'value', 'entity': 'At least 20'}]},
#  {'text': '- At least four sites with probing depth ≥ 5 mm and clinical attachment loss ≥ 3 mm',
#   'entities': [{'label': 'lab_test', 'entity': 'probing depth'},
#    {'label': 'operator', 'entity': '≥'},
#    {'label': 'value', 'entity': '5 mm'},
#    {'label': 'lab_test', 'entity': 'clinical attachment loss'},
#    {'label': 'operator', 'entity': '≥'},
#    {'label': 'value', 'entity': '3 mm'}]},
#  {'text': 'Exclusion criteria:', 'entities': []},
#  {'text': '- Patients with systemic diseases that may affect periodontal tissues',
#   'entities': [{'label': 'condition', 'entity': 'systemic diseases'}]},
#  {'text': '- Patients taking medications that may affect periodontal tissues',
#   'entities': [{'label': 'drug', 'entity': 'medications'}]},
#  {'text': '- Pregnant or breastfeeding women',
#   'entities': [{'label': 'demographic',
#     'entity': 'Pregnant or breastfeeding women'}]},
#  {'text': '- Smokers',
#   'entities': [{'label': 'demographic', 'entity': 'Smokers'}]},
#  {'text': '- Patients who have had periodontal surgery in the past 12 months',
#   'entities': [{'label': 'procedure', 'entity': 'periodontal surgery'},
#    {'label': 'value', 'entity': '12 months'}]},
#  {'text': 'Inclusion Criteria:', 'entities': []},
#  {'text': '- Histologically confirmed diagnosis of advanced or metastatic gastric or gastroesophageal junction adenocarcinoma',
#   'entities': [{'label': 'condition',
#     'entity': 'advanced or metastatic gastric or gastroesophageal junction adenocarcinoma'}]},
#  {'text': '- Progression of disease after two or more prior lines of systemic therapy',
#   'entities': [{'label': 'condition', 'entity': 'Progression of disease'},
#    {'label': 'drug', 'entity': 'systemic therapy'}]},
#  {'text': '- Age ≥18 years',
#   'entities': [{'label': 'demographic', 'entity': 'Age ≥18 years'}]},
#  {'text': '- ECOG performance status 0-1',
#   'entities': [{'label': 'lab_test', 'entity': 'ECOG performance status'},
#    {'label': 'value', 'entity': '0-1'}]},
#  {'text': '- Life expectancy ≥3 months',
#   'entities': [{'label': 'operator', 'entity': '≥'},
#    {'label': 'value', 'entity': '3 months'}]},
#  {'text': '- Adequate organ function', 'entities': []},
#  {'text': 'Exclusion Criteria:', 'entities': []},
#  {'text': '- Prior treatment with trifluridine/tipiracil',
#   'entities': [{'label': 'drug', 'entity': 'trifluridine/tipiracil'}]},
#  {'text': '- Active brain metastases',
#   'entities': [{'label': 'condition', 'entity': 'Active brain metastases'}]},
#  {'text': '- History of another malignancy within the past 5 years, except for adequately treated non-melanoma skin cancer or in situ cervical cancer',
#   'entities': [{'label': 'condition', 'entity': 'malignancy'},
#    {'label': 'value', 'entity': '5 years'},
#    {'label': 'condition', 'entity': 'non-melanoma skin cancer'},
#    {'label': 'condition', 'entity': 'in situ cervical cancer'}]},
#  {'text': '- Uncontrolled ascites requiring therapeutic paracentesis more than once every 4 weeks',
#   'entities': [{'label': 'condition', 'entity': 'Uncontrolled ascites'},
#    {'label': 'procedure', 'entity': 'therapeutic paracentesis'},
#    {'label': 'value', 'entity': 'more than once every 4 weeks'}]},
#  {'text': 'Inclusion Criteria:', 'entities': []},
#  {'text': '- Histologically confirmed diagnosis of hepatocellular carcinoma (HCC)',
#   'entities': [{'label': 'condition',
#     'entity': 'hepatocellular carcinoma (HCC)'}]},
#  {'text': '- Unresectable or metastatic disease',
#   'entities': [{'label': 'condition',
#     'entity': 'Unresectable or metastatic disease'}]},
#  {'text': '- No prior systemic therapy for HCC',
#   'entities': [{'label': 'drug', 'entity': 'systemic therapy'},
#    {'label': 'condition', 'entity': 'HCC'}]},
#  {'text': '- Child-Pugh class A liver function',
#   'entities': [{'label': 'lab_test',
#     'entity': 'Child-Pugh class A liver function'}]},
#  {'text': '- ECOG performance status 0-1',
#   'entities': [{'label': 'lab_test', 'entity': 'ECOG performance status'},
#    {'label': 'value', 'entity': '0-1'}]},
#  {'text': '- Age ≥18 years',
#   'entities': [{'label': 'demographic', 'entity': 'Age ≥18 years'}]},
#  {'text': '- Life expectancy ≥3 months',
#   'entities': [{'label': 'operator', 'entity': '≥'},
#    {'label': 'value', 'entity': '3 months'}]},
#  {'text': '- Adequate organ and bone marrow function', 'entities': []},
#  {'text': 'Exclusion Criteria:', 'entities': []},
#  {'text': '- Prior liver transplantation',
#   'entities': [{'label': 'procedure', 'entity': 'liver transplantation'}]},
#  {'text': '- Active brain metastases',
#   'entities': [{'label': 'condition', 'entity': 'Active brain metastases'}]},
#  {'text': '- History of other malignancy within the past 5 years, with the exception of adequately treated non-melanoma skin cancer or cervical carcinoma in situ',
#   'entities': [{'label': 'condition', 'entity': 'malignancy'},
#    {'label': 'value', 'entity': '5 years'},
#    {'label': 'condition', 'entity': 'non-melanoma skin cancer'},
#    {'label': 'condition', 'entity': 'cervical carcinoma in situ'}]},
#  {'text': '- Known hypersensitivity to sorafenib or lenvatinib',
#   'entities': [{'label': 'condition', 'entity': 'hypersensitivity'},
#    {'label': 'drug', 'entity': 'sorafenib'},
#    {'label': 'drug', 'entity': 'lenvatinib'}]},
#  {'text': 'Inclusion Criteria:', 'entities': []},
#  {'text': '- Histologically confirmed diagnosis of advanced or metastatic soft tissue sarcoma',
#   'entities': [{'label': 'condition',
#     'entity': 'advanced or metastatic soft tissue sarcoma'}]},
#  {'text': '- Progression of disease after standard therapies, including an anthracycline-containing regimen',
#   'entities': [{'label': 'condition', 'entity': 'Progression of disease'},
# ...
#  {'text': '- Presence of a RET gene fusion',
#   'entities': [{'label': 'condition', 'entity': 'RET gene fusion'}]},
#  {'text': '- Age ≥12 years',
#   'entities': [{'label': 'demographic', 'entity': 'Age ≥12 years'}]},
#  {'text': '- ECOG performance status 0-1',
#   'entities': [{'label': 'lab_test', 'entity': 'ECOG performance status'},
#    {'label': 'value', 'entity': '0-1'}]},
#  {'text': '- Measurable disease',
#   'entities': [{'label': 'condition', 'entity': 'Measurable disease'}]},
#  {'text': '- Adequate organ function', 'entities': []},
#  {'text': 'Exclusion Criteria:', 'entities': []},
#  {'text': '- Prior treatment with a selective RET inhibitor',
#   'entities': [{'label': 'drug', 'entity': 'selective RET inhibitor'}]},
#  {'text': '- Active brain metastases',
#   'entities': [{'label': 'condition', 'entity': 'Active brain metastases'}]},
#  {'text': '- History of interstitial lung disease or pneumonitis',
#   'entities': [{'label': 'condition', 'entity': 'interstitial lung disease'},
#    {'label': 'condition', 'entity': 'pneumonitis'}]},
#  {'text': '- Significant cardiovascular disease',
#   'entities': [{'label': 'condition', 'entity': 'cardiovascular disease'}]},
#  {'text': 'Inclusion Criteria:', 'entities': []},
#  {'text': '- Patients with a histologically confirmed diagnosis of a solid tumor that is metastatic or unresectable and has progressed following prior treatment and for which no satisfactory alternative therapy exists.',
#   'entities': [{'label': 'condition',
#     'entity': 'solid tumor that is metastatic or unresectable and has progressed following prior treatment'}]},
#  {'text': '- Patients must have a tumor with a high tumor mutational burden (TMB-H) [≥10 mutations/megabase (mut/Mb)] as determined by the FoundationOne CDx assay.',
#   'entities': [{'label': 'condition',
#     'entity': 'tumor with a high tumor mutational burden (TMB-H)'},
#    {'label': 'operator', 'entity': '≥'},
#    {'label': 'value', 'entity': '10 mutations/megabase (mut/Mb)'},
#    {'label': 'lab_test', 'entity': 'FoundationOne CDx assay'}]},
#  {'text': '- Patients must have measurable disease as per RECIST v1.1.',
#   'entities': [{'label': 'condition', 'entity': 'measurable disease'}]},
#  {'text': '- Patients must have an Eastern Cooperative Oncology Group (ECOG) performance status of 0 or 1.',
#   'entities': [{'label': 'lab_test',
#     'entity': 'Eastern Cooperative Oncology Group (ECOG) performance status'},
#    {'label': 'value', 'entity': '0 or 1'}]},
#  {'text': '- Patients must have a life expectancy of at least 3 months.',
#   'entities': [{'label': 'value', 'entity': 'at least 3 months'}]},
#  {'text': '- Patients must have adequate organ function.', 'entities': []},
#  {'text': 'Exclusion Criteria:', 'entities': []},
#  {'text': '- Patients who have had prior treatment with an anti-PD-1, anti-PD-L1, or anti-CTLA-4 antibody.',
#   'entities': [{'label': 'drug',
#     'entity': 'anti-PD-1, anti-PD-L1, or anti-CTLA-4 antibody'}]},
#  {'text': '- Patients with a known hypersensitivity to pembrolizumab or any of its excipients.',
#   'entities': [{'label': 'condition', 'entity': 'hypersensitivity'},
#    {'label': 'drug', 'entity': 'pembrolizumab'}]},
#  {'text': '- Patients with an active autoimmune disease that has required systemic treatment in the past 2 years.',
#   'entities': [{'label': 'condition', 'entity': 'autoimmune disease'},
#    {'label': 'drug', 'entity': 'systemic treatment'},
#    {'label': 'value', 'entity': '2 years'}]},
#  {'text': '- Patients with a medical condition that requires systemic corticosteroids or other immunosuppressive medications.',
#   'entities': [{'label': 'condition', 'entity': 'medical condition'},
#    {'label': 'drug', 'entity': 'systemic corticosteroids'},
#    {'label': 'drug', 'entity': 'immunosuppressive medications'}]},
#  {'text': 'Inclusion Criteria:', 'entities': []},
#  {'text': '- Histologically confirmed diagnosis of a solid tumor that is metastatic or unresectable',
#   'entities': [{'label': 'condition',
#     'entity': 'solid tumor that is metastatic or unresectable'}]},
#  {'text': '- Progression on or after prior standard therapy',
#   'entities': [{'label': 'condition',
#     'entity': 'Progression on or after prior standard therapy'}]},
#  {'text': '- Presence of a MET exon 14 skipping mutation',
#   'entities': [{'label': 'condition',
#     'entity': 'MET exon 14 skipping mutation'}]},
#  {'text': '- Age ≥18 years',
#   'entities': [{'label': 'demographic', 'entity': 'Age ≥18 years'}]},
#  {'text': '- ECOG performance status 0-1',
#   'entities': [{'label': 'lab_test', 'entity': 'ECOG performance status'},
#    {'label': 'value', 'entity': '0-1'}]},
#  {'text': '- Measurable disease',
#   'entities': [{'label': 'condition', 'entity': 'Measurable disease'}]},
#  {'text': '- Adequate organ function', 'entities': []},
#  {'text': 'Exclusion Criteria:', 'entities': []},
#  {'text': '- Prior treatment with a MET inhibitor',
#   'entities': [{'label': 'drug', 'entity': 'MET inhibitor'}]},
#  {'text': '- Active brain metastases',
#   'entities': [{'label': 'condition', 'entity': 'Active brain metastases'}]},
#  {'text': '- History of interstitial lung disease or pneumonitis',
#   'entities': [{'label': 'condition', 'entity': 'interstitial lung disease'},
#    {'label': 'condition', 'entity': 'pneumonitis'}]},
#  {'text': '- Significant cardiovascular disease',
#   'entities': [{'label': 'condition', 'entity': 'cardiovascular disease'}]},
#  {'text': 'Inclusion Criteria:', 'entities': []},
#  {'text': '- Histologically confirmed diagnosis of a solid tumor that is metastatic or unresectable',
#   'entities': [{'label': 'condition',
#     'entity': 'solid tumor that is metastatic or unresectable'}]},
#  {'text': '- Progression on or after prior standard therapy',
#   'entities': [{'label': 'condition',
#     'entity': 'Progression on or after prior standard therapy'}]},
#  {'text': '- Presence of a KRAS G12C mutation',
#   'entities': [{'label': 'condition', 'entity': 'KRAS G12C mutation'}]},
#  {'text': '- Age ≥18 years',
#   'entities': [{'label': 'demographic', 'entity': 'Age ≥18 years'}]},
#  {'text': '- ECOG performance status 0-1',
#   'entities': [{'label': 'lab_test', 'entity': 'ECOG performance status'},
#    {'label': 'value', 'entity': '0-1'}]},
#  {'text': '- Measurable disease',
#   'entities': [{'label': 'condition', 'entity': 'Measurable disease'}]},
#  {'text': '- Adequate organ function', 'entities': []},
#  {'text': 'Exclusion Criteria:', 'entities': []},
#  {'text': '- Prior treatment with a KRAS G12C inhibitor',
#   'entities': [{'label': 'drug', 'entity': 'KRAS G12C inhibitor'}]},
#  {'text': '- Active brain metastases',
#   'entities': [{'label': 'condition', 'entity': 'Active brain metastases'}]},
#  {'text': '- History of interstitial lung disease or pneumonitis',
#   'entities': [{'label': 'condition', 'entity': 'interstitial lung disease'},
#    {'label': 'condition', 'entity': 'pneumonitis'}]},
#  {'text': '- Significant cardiovascular disease',
#   'entities': [{'label': 'condition', 'entity': 'cardiovascular disease'}]},
#  {'text': 'Inclusion criteria:', 'entities': []},
#  {'text': '- Patients with a diagnosis of a solid tumor that is metastatic or unresectable and for which standard therapy is not available or is no longer effective',
#   'entities': [{'label': 'condition',
#     'entity': 'solid tumor that is metastatic or unresectable'}]},
#  {'text': '- Patients must have a tumor that harbors a BRAF V600E mutation',
#   'entities': [{'label': 'condition',
#     'entity': 'tumor that harbors a BRAF V600E mutation'}]},
#  {'text': '- Patients must have measurable disease',
#   'entities': [{'label': 'condition', 'entity': 'measurable disease'}]},
#  {'text': '- Patients must be at least 18 years old',
#   'entities': [{'label': 'demographic', 'entity': 'at least 18 years old'}]},
#  {'text': '- Patients must have an ECOG performance status of 0 or 1',
#   'entities': [{'label': 'lab_test', 'entity': 'ECOG performance status'},
#    {'label': 'value', 'entity': '0 or 1'}]},
#  {'text': '- Patients must have adequate organ function', 'entities': []},
#  {'text': 'Exclusion criteria:', 'entities': []},
#  {'text': '- Patients who have received prior treatment with a BRAF or MEK inhibitor',
#   'entities': [{'label': 'drug', 'entity': 'BRAF or MEK inhibitor'}]},
#  {'text': '- Patients with a history of retinal vein occlusion',
#   'entities': [{'label': 'condition', 'entity': 'retinal vein occlusion'}]},
#  {'text': '- Patients with a history of interstitial lung disease or pneumonitis',
#   'entities': [{'label': 'condition', 'entity': 'interstitial lung disease'},
#    {'label': 'condition', 'entity': 'pneumonitis'}]},
#  {'text': '- Patients with a known hypersensitivity to dabrafenib or trametinib',
#   'entities': [{'label': 'condition', 'entity': 'hypersensitivity'},
#    {'label': 'drug', 'entity': 'dabrafenib'},
#    {'label': 'drug', 'entity': 'trametinib'}]},
#  {'text': 'Inclusion Criteria:', 'entities': []},
#  {'text': '- Histologically confirmed diagnosis of a solid tumor that is metastatic or unresectable and for which there is no available standard therapy',
#   'entities': [{'label': 'condition',
#     'entity': 'solid tumor that is metastatic or unresectable'}]},
#  {'text': '- Presence of an IDH1 or IDH2 mutation',
#   'entities': [{'label': 'condition', 'entity': 'IDH1 or IDH2 mutation'}]},
#  {'text': '- Age ≥18 years',
#   'entities': [{'label': 'demographic', 'entity': 'Age ≥18 years'}]},
#  {'text': '- ECOG performance status 0-1',
#   'entities': [{'label': 'lab_test', 'entity': 'ECOG performance status'},
#    {'label': 'value', 'entity': '0-1'}]},
#  {'text': '- Measurable disease',
#   'entities': [{'label': 'condition', 'entity': 'Measurable disease'}]},
#  {'text': '- Adequate organ function', 'entities': []},
#  {'text': 'Exclusion Criteria:', 'entities': []},
#  {'text': '- Prior treatment with an IDH1 or IDH2 inhibitor',
#   'entities': [{'label': 'drug', 'entity': 'IDH1 or IDH2 inhibitor'}]},
#  {'text': '- Active brain metastases',
#   'entities': [{'label': 'condition', 'entity': 'Active brain metastases'}]},
#  {'text': '- History of retinal pigment epithelial detachment',
#   'entities': [{'label': 'condition',
#     'entity': 'retinal pigment epithelial detachment'}]},
#  {'text': '- Significant cardiovascular disease',
#   'entities': [{'label': 'condition', 'entity': 'cardiovascular disease'}]},
#  {'text': 'Inclusion Criteria:', 'entities': []},
#  {'text': '- Histologically confirmed diagnosis of a solid tumor that is metastatic or unresectable',
#   'entities': [{'label': 'condition',
#     'entity': 'solid tumor that is metastatic or unresectable'}]},
#  {'text': '- Progression on or after prior standard therapy',
#   'entities': [{'label': 'condition',
#     'entity': 'Progression on or after prior standard therapy'}]},
#  {'text': '- Presence of an ALK rearrangement',
#   'entities': [{'label': 'condition', 'entity': 'ALK rearrangement'}]},
#  {'text': '- Age ≥18 years',
#   'entities': [{'label': 'demographic', 'entity': 'Age ≥18 years'}]},
#  {'text': '- ECOG performance status 0-2',
#   'entities': [{'label': 'lab_test', 'entity': 'ECOG performance status'},
#    {'label': 'value', 'entity': '0-2'}]},
#  {'text': '- Measurable disease',
#   'entities': [{'label': 'condition', 'entity': 'Measurable disease'}]},
#  {'text': '- Adequate organ function', 'entities': []},
#  {'text': 'Exclusion Criteria:', 'entities': []},
#  {'text': '- Prior treatment with an ALK inhibitor',
#   'entities': [{'label': 'drug', 'entity': 'ALK inhibitor'}]},
#  {'text': '- Active brain metastases',
#   'entities': [{'label': 'condition', 'entity': 'Active brain metastases'}]},
#  {'text': '- History of interstitial lung disease or pneumonitis',
#   'entities': [{'label': 'condition', 'entity': 'interstitial lung disease'},
#    {'label': 'condition', 'entity': 'pneumonitis'}]},
#  {'text': '- Significant cardiovascular disease',
#   'entities': [{'label': 'condition', 'entity': 'cardiovascular disease'}]},
#  {'text': 'Inclusion Criteria:', 'entities': []},
#  {'text': '- Histologically confirmed diagnosis of a solid tumor that is metastatic or unresectable and for which there is no available standard therapy',
#   'entities': [{'label': 'condition',
#     'entity': 'solid tumor that is metastatic or unresectable'}]},
#  {'text': '- Presence of a ROS1 rearrangement',
#   'entities': [{'label': 'condition', 'entity': 'ROS1 rearrangement'}]},
#  {'text': '- Age ≥18 years',
#   'entities': [{'label': 'demographic', 'entity': 'Age ≥18 years'}]},
#  {'text': '- ECOG performance status 0-1',
#   'entities': [{'label': 'lab_test', 'entity': 'ECOG performance status'},
#    {'label': 'value', 'entity': '0-1'}]},
#  {'text': '- Measurable disease',
#   'entities': [{'label': 'condition', 'entity': 'Measurable disease'}]},
#  {'text': '- Adequate organ function', 'entities': []},
#  {'text': 'Exclusion Criteria:', 'entities': []},
#  {'text': '- Prior treatment with a ROS1 inhibitor',
#   'entities': [{'label': 'drug', 'entity': 'ROS1 inhibitor'}]},
#  {'text': '- Active brain metastases',
#   'entities': [{'label': 'condition', 'entity': 'Active brain metastases'}]},
#  {'text': '- History of interstitial lung disease or pneumonitis',
#   'entities': [{'label': 'condition', 'entity': 'interstitial lung disease'},
#    {'label': 'condition', 'entity': 'pneumonitis'}]},
#  {'text': '- Significant cardiovascular disease',
#   'entities': [{'label': 'condition', 'entity': 'cardiovascular disease'}]},
#  {'text': 'Inclusion Criteria:', 'entities': []},
#  {'text': '- Histologically confirmed diagnosis of a solid tumor that is metastatic or unresectable',
#   'entities': [{'label': 'condition',
#     'entity': 'solid tumor that is metastatic or unresectable'}]},
#  {'text': '- Progression on or after prior standard therapy',
#   'entities': [{'label': 'condition',
#     'entity': 'Progression on or after prior standard therapy'}]},
#  {'text': '- Presence of a PIK3CA mutation',
#   'entities': [{'label': 'condition', 'entity': 'PIK3CA mutation'}]},
#  {'text': '- Age ≥18 years',
#   'entities': [{'label': 'demographic', 'entity': 'Age ≥18 years'}]},
#  {'text': '- ECOG performance status 0-1',
#   'entities': [{'label': 'lab_test', 'entity': 'ECOG performance status'},
#    {'label': 'value', 'entity': '0-1'}]},
#  {'text': '- Measurable disease',
#   'entities': [{'label': 'condition', 'entity': 'Measurable disease'}]},
#  {'text': '- Adequate organ function', 'entities': []},
#  {'text': 'Exclusion Criteria:', 'entities': []},
#  {'text': '- Prior treatment with a PI3K inhibitor',
#   'entities': [{'label': 'drug', 'entity': 'PI3K inhibitor'}]},
#  {'text': '- Active brain metastases',
#   'entities': [{'label': 'condition', 'entity': 'Active brain metastases'}]},
#  {'text': '- History of severe cutaneous reactions to alpelisib',
#   'entities': [{'label': 'condition', 'entity': 'severe cutaneous reactions'},
#    {'label': 'drug', 'entity': 'alpelisib'}]},
#  {'text': '- Uncontrolled diabetes',
#   'entities': [{'label': 'condition', 'entity': 'Uncontrolled diabetes'}]},
#  {'text': 'Inclusion Criteria:', 'entities': []},
#  {'text': '- Histologically confirmed diagnosis of a solid tumor that is metastatic or unresectable',
#   'entities': [{'label': 'condition',
#     'entity': 'solid tumor that is metastatic or unresectable'}]},
#  {'text': '- Progression on or after prior standard therapy',
#   'entities': [{'label': 'condition',
#     'entity': 'Progression on or after prior standard therapy'}]},
#  {'text': '- Presence of a BRCA1 or BRCA2 mutation',
#   'entities': [{'label': 'condition', 'entity': 'BRCA1 or BRCA2 mutation'}]},
#  {'text': '- Age ≥18 years',
#   'entities': [{'label': 'demographic', 'entity': 'Age ≥18 years'}]},
#  {'text': '- ECOG performance status 0-1',
#   'entities': [{'label': 'lab_test', 'entity': 'ECOG performance status'},
#    {'label': 'value', 'entity': '0-1'}]},
#  {'text': '- Measurable disease',
#   'entities': [{'label': 'condition', 'entity': 'Measurable disease'}]},
#  {'text': '- Adequate organ function', 'entities': []},
#  {'text': 'Exclusion Criteria:', 'entities': []},
#  {'text': '- Prior treatment with a PAR',
#   'entities': [{'label': 'drug', 'entity': 'PAR'}]}]

# %%
dataset = Dataset.from_dict({
    "text": [item["text"] for item in raw_data],
    "ner_tags_spans": [item.get("label", []) for item in raw_data]
})
print(f"Loaded {len(dataset)} annotated examples from '{ANNOTATION_FILE}'.")
# Out:
# Loaded 543 annotated examples from '../data\processed\all.json'.

# %%
tag_names = ['O'] + [f'{prefix}-{tag}' for tag in LABELS for prefix in ['B', 'I']]
tag2id = {tag: i for i, tag in enumerate(tag_names)}
id2tag = {i: tag for tag, i in tag2id.items()}

# %%
tokenizer = AutoTokenizer.from_pretrained(MODEL_CHECKPOINT)

# %%
def tokenize_and_align_labels(examples):
    tokenized_inputs = tokenizer(examples["text"], truncation=True, is_split_into_words=False)
    all_labels = []
    for i, spans in enumerate(examples["ner_tags_spans"]):
        word_ids = tokenized_inputs.word_ids(batch_index=i)
        label_ids = {} 
        for start, end, label in spans:
            for token_idx in range(len(tokenized_inputs.input_ids[i])):
                char_start, char_end = tokenized_inputs.token_to_chars(i, token_idx)
                if char_start is None: continue
                
                if max(start, char_start) < min(end, char_end):
                    word_id = word_ids[token_idx]
                    if word_id is not None:
                        prefix = "B"
                        if token_idx > 0 and word_ids[token_idx-1] == word_id:
                            if label_ids.get(word_id) is not None:
                                prefix = "I"
                        
                        tag = f"{prefix}-{label}"
                        if tag in tag2id:
                            label_ids[word_id] = tag2id[tag]
                        else:
                            print(f"Warning: Label '{label}' not found in schema. Skipping.")
        
        final_labels = []
        previous_word_idx = None
        for word_idx in word_ids:
            if word_idx is None:
                final_labels.append(-100)
            else:
                label_id = label_ids.get(word_idx)
                if label_id is not None:

                    if word_idx == previous_word_idx:
                        tag = tag_names[label_id].replace("B-", "I-")
                        final_labels.append(tag2id.get(tag, label_id))
                    else:
                        final_labels.append(label_id)
                else:
                    final_labels.append(tag2id['O'])
            previous_word_idx = word_idx
        all_labels.append(final_labels)

    tokenized_inputs["labels"] = all_labels
    return tokenized_inputs

# %%
print("\nTokenizing text and aligning labels with the IOB2 scheme...")
tokenized_dataset = dataset.map(
    tokenize_and_align_labels,
    batched=True,
    remove_columns=dataset.column_names
)
# Out:
# Tokenizing text and aligning labels with the IOB2 scheme...
# Map:   0%|          | 0/543 [00:00<?, ? examples/s]Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Map: 100%|██████████| 543/543 [00:00<00:00, 20529.92 examples/s]

# %%
tokenized_dataset
# Out:
# Dataset({
#     features: ['input_ids', 'token_type_ids', 'attention_mask', 'labels'],
#     num_rows: 543
# })

# %%
final_dataset = tokenized_dataset.train_test_split(test_size=0.1, seed=42)
print("\nSplitting data into a training set (90%) and an evaluation set (10%):")
print(final_dataset)
# Out:
# Splitting data into a training set (90%) and an evaluation set (10%):
# DatasetDict({
#     train: Dataset({
#         features: ['input_ids', 'token_type_ids', 'attention_mask', 'labels'],
#         num_rows: 488
#     })
#     test: Dataset({
#         features: ['input_ids', 'token_type_ids', 'attention_mask', 'labels'],
#         num_rows: 55
#     })
# })

# %%
final_dataset.save_to_disk(OUTPUT_DATASET_FOLDER)
print(f"\nProcessed dataset saved to '{OUTPUT_DATASET_FOLDER}'. Ready for training.")
# Out:
# Saving the dataset (1/1 shards): 100%|██████████| 488/488 [00:00<00:00, 37081.42 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 55/55 [00:00<00:00, 4231.00 examples/s]
# Processed dataset saved to '../data\ner_dataset'. Ready for training.
